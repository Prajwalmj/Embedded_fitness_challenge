# %%
import numpy as np
#x_sq_1, y_sq_1, z_sq_1 = np.loadtxt('squat_1.csv', delimiter=",", unpack = True)
data_sq = np.loadtxt('squat_1.csv', delimiter=",", usecols=range(3))

# %%
x_sq_1 = np.zeros((data_sq.shape[0]//2))
y_sq_1 = np.zeros((data_sq.shape[0]//2))
z_sq_1 = np.zeros((data_sq.shape[0]//2))
ang_x_sq_1 = np.zeros((data_sq.shape[0]//2))
ang_y_sq_1 = np.zeros((data_sq.shape[0]//2))
ang_z_sq_1 = np.zeros((data_sq.shape[0]//2))
for i in range((data_sq.shape[0])//2):
    x_sq_1[i] = data_sq[(2*i),0]
    y_sq_1[i] = data_sq[(2*i),1]
    z_sq_1[i] = data_sq[(2*i),2]
    ang_x_sq_1[i] = data_sq[(2*i)+1,0]
    ang_y_sq_1[i] = data_sq[(2*i)+1,1]
    ang_z_sq_1[i] = data_sq[(2*i)+1,2]

# %%
import matplotlib.pyplot as plt

# %%
t_sq_1 = np.arange(start=0, stop=x_sq_1.shape[0], step=1)

# %%
sq_mean_10 = np.mean(y_sq_1[:10])
sq_std_10 = np.std(y_sq_1[:10])
print(sq_mean_10)
print(sq_std_10)
sq_mean_20 = np.mean(y_sq_1[:20])
sq_std_20 = np.std(y_sq_1[:20])
print(sq_mean_20)
print(sq_std_20)
# Out:
# -16429.1
# 395.814716755201
# -16833.75
# 2280.112516412293

# %%
plt.plot(t_sq_1, y_sq_1)
plt.grid()
plt.title('Squat y')
# Out:
# Text(0.5,1,'Squat y')

# %%
plt.plot(t_sq_1, z_sq_1)
plt.grid()
plt.title('Squat z')
# Out:
# Text(0.5,1,'Squat z')

# %%
plt.plot(t_sq_1, ang_x_sq_1)
plt.grid()
plt.title('Squat Angle x')
# Out:
# Text(0.5,1,'Squat Angle x')

# %%
plt.plot(t_sq_1, ang_y_sq_1)
plt.grid()
plt.title('Squat Angle y')
# Out:
# Text(0.5,1,'Squat Angle y')

# %%
plt.plot(t_sq_1, ang_z_sq_1)
plt.grid()
plt.title('Squat Angle z')
# Out:
# Text(0.5,1,'Squat Angle z')

# %%
data_sq_2 = np.loadtxt('squat_2.csv', delimiter=",", usecols=range(3))

# %%
x_sq_2 = np.zeros((data_sq_2.shape[0]//2))
y_sq_2 = np.zeros((data_sq_2.shape[0]//2))
z_sq_2 = np.zeros((data_sq_2.shape[0]//2))
ang_x_sq_2 = np.zeros((data_sq_2.shape[0]//2))
ang_y_sq_2 = np.zeros((data_sq_2.shape[0]//2))
ang_z_sq_2 = np.zeros((data_sq_2.shape[0]//2))
for i in range((data_sq_2.shape[0])//2):
    x_sq_2[i] = data_sq_2[(2*i),0]
    y_sq_2[i] = data_sq_2[(2*i),1]
    z_sq_2[i] = data_sq_2[(2*i),2]
    ang_x_sq_2[i] = data_sq_2[(2*i)+1,0]
    ang_y_sq_2[i] = data_sq_2[(2*i)+1,1]
    ang_z_sq_2[i] = data_sq_2[(2*i)+1,2]

# %%
t_sq_2 = np.arange(start=0, stop=x_sq_2.shape[0], step=1)

# %%
data_sq_3 = np.loadtxt('squat_3.csv', delimiter=",", usecols=range(3))

# %%
x_sq_3 = np.zeros((data_sq_3.shape[0]//2))
y_sq_3 = np.zeros((data_sq_3.shape[0]//2))
z_sq_3 = np.zeros((data_sq_3.shape[0]//2))
ang_x_sq_3 = np.zeros((data_sq_3.shape[0]//2))
ang_y_sq_3 = np.zeros((data_sq_3.shape[0]//2))
ang_z_sq_3 = np.zeros((data_sq_3.shape[0]//2))
for i in range((data_sq_3.shape[0])//2):
    x_sq_3[i] = data_sq_3[(2*i),0]
    y_sq_3[i] = data_sq_3[(2*i),1]
    z_sq_3[i] = data_sq_3[(2*i),2]
    ang_x_sq_3[i] = data_sq_3[(2*i)+1,0]
    ang_y_sq_3[i] = data_sq_3[(2*i)+1,1]
    ang_z_sq_3[i] = data_sq_3[(2*i)+1,2]

# %%
t_sq_3 = np.arange(start=0, stop=x_sq_3.shape[0], step=1)

# %%
data_sq_4 = np.loadtxt('squat_4.csv', delimiter=",", usecols=range(3))

# %%
x_sq_4 = np.zeros((data_sq_4.shape[0]//2))
y_sq_4 = np.zeros((data_sq_4.shape[0]//2))
z_sq_4 = np.zeros((data_sq_4.shape[0]//2))
ang_x_sq_4 = np.zeros((data_sq_4.shape[0]//2))
ang_y_sq_4 = np.zeros((data_sq_4.shape[0]//2))
ang_z_sq_4 = np.zeros((data_sq_4.shape[0]//2))
for i in range((data_sq_4.shape[0])//2):
    x_sq_4[i] = data_sq_4[(2*i),0]
    y_sq_4[i] = data_sq_4[(2*i),1]
    z_sq_4[i] = data_sq_4[(2*i),2]
    ang_x_sq_4[i] = data_sq_4[(2*i)+1,0]
    ang_y_sq_4[i] = data_sq_4[(2*i)+1,1]
    ang_z_sq_4[i] = data_sq_4[(2*i)+1,2]

# %%
t_sq_4 = np.arange(start=0, stop=x_sq_4.shape[0], step=1)

# %%
data_sq_5 = np.loadtxt('squat_5.csv', delimiter=",", usecols=range(3))

# %%
x_sq_5 = np.zeros((data_sq_5.shape[0]//2))
y_sq_5 = np.zeros((data_sq_5.shape[0]//2))
z_sq_5 = np.zeros((data_sq_5.shape[0]//2))
ang_x_sq_5 = np.zeros((data_sq_5.shape[0]//2))
ang_y_sq_5 = np.zeros((data_sq_5.shape[0]//2))
ang_z_sq_5 = np.zeros((data_sq_5.shape[0]//2))
for i in range((data_sq_5.shape[0])//2):
    x_sq_5[i] = data_sq_5[(2*i),0]
    y_sq_5[i] = data_sq_5[(2*i),1]
    z_sq_5[i] = data_sq_5[(2*i),2]
    ang_x_sq_5[i] = data_sq_5[(2*i)+1,0]
    ang_y_sq_5[i] = data_sq_5[(2*i)+1,1]
    ang_z_sq_5[i] = data_sq_5[(2*i)+1,2]

# %%
t_sq_5 = np.arange(start=0, stop=x_sq_5.shape[0], step=1)

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_sq_2, y_sq_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_sq_3, y_sq_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_sq_4, y_sq_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_sq_5, y_sq_5)
plt.grid()


plt.title('y acceleration')
plt.show()

# %%
print('threshold is -14,000 and -20,000')
# Out:
# threshold is -14,000 and -20,000

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_sq_2, z_sq_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_sq_3, z_sq_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_sq_4, z_sq_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_sq_5, z_sq_5)
plt.grid()


plt.title('z acceleration')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_sq_2, ang_y_sq_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_sq_3, ang_y_sq_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_sq_4, ang_y_sq_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_sq_5, ang_y_sq_5)
plt.grid()


plt.title('angle y')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_sq_2, ang_z_sq_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_sq_3, ang_z_sq_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_sq_4, ang_z_sq_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_sq_5, ang_z_sq_5)
plt.grid()


plt.title('angle z')
plt.show()

# %%
print('No patter in angle y or z, that can be used!, probably even z acceleration?!')
# Out:
# No patter in angle y or z, that can be used!, probably even z acceleration?!

# %%
sq_mean = []
sq_std = []
sq_mean.append(np.mean(y_sq_1[:20]))
sq_std.append(np.std(y_sq_1[:20]))
sq_mean.append(np.mean(y_sq_2[:20]))
sq_std.append(np.std(y_sq_2[:20]))
sq_mean.append(np.mean(y_sq_3[:20]))
sq_std.append(np.std(y_sq_3[:20]))
sq_mean.append(np.mean(y_sq_4[:20]))
sq_std.append(np.std(y_sq_4[:20]))
sq_mean.append(np.mean(y_sq_5[:20]))
sq_std.append(np.std(y_sq_5[:20]))
print('Mean -', sq_mean)
print('Std -', sq_std)
# Out:
# Mean - [-16833.75, -16548.4, -16445.2, -16448.9, -16160.8]
# Std - [2280.112516412293, 2638.8442053292956, 2898.8630460923814, 2484.4190246413746, 2975.8451673432205]

# %%
sq_mean = []
sq_std = []
sq_mean.append(np.mean(z_sq_1[:20]))
sq_std.append(np.std(z_sq_1[:20]))
sq_mean.append(np.mean(z_sq_2[:20]))
sq_std.append(np.std(z_sq_2[:20]))
sq_mean.append(np.mean(z_sq_3[:20]))
sq_std.append(np.std(z_sq_3[:20]))
sq_mean.append(np.mean(z_sq_4[:20]))
sq_std.append(np.std(z_sq_4[:20]))
sq_mean.append(np.mean(z_sq_5[:20]))
sq_std.append(np.std(z_sq_5[:20]))
print('Mean -', sq_mean)
print('Std -', sq_std)
# Out:
# Mean - [-2509.9, -3448.25, -4138.4, -2086.65, -2447.4]
# Std - [1240.4981217236889, 1648.3882999766772, 1761.114090568808, 1497.863020272548, 2218.7203834643065]

# %%
sq_mean = []
sq_std = []
sq_mean.append(np.mean(z_sq_1[:10]))
sq_std.append(np.std(z_sq_1[:10]))
sq_mean.append(np.mean(z_sq_2[:10]))
sq_std.append(np.std(z_sq_2[:10]))
sq_mean.append(np.mean(z_sq_3[:10]))
sq_std.append(np.std(z_sq_3[:10]))
sq_mean.append(np.mean(z_sq_4[:10]))
sq_std.append(np.std(z_sq_4[:10]))
sq_mean.append(np.mean(z_sq_5[:10]))
sq_std.append(np.std(z_sq_5[:10]))
print('Mean -', sq_mean)
print('Std -', sq_std)
# Out:
# Mean - [-1954.7, -2296.0, -3015.1, -1331.3, -726.4]
# Std - [400.32737852912334, 927.9717668119004, 1046.685860227413, 1507.4501019934291, 959.4878008604383]

# %%
sq_mean = []
sq_std = []
sq_mean.append(np.mean(y_sq_1[:10]))
sq_std.append(np.std(y_sq_1[:10]))
sq_mean.append(np.mean(y_sq_2[:10]))
sq_std.append(np.std(y_sq_2[:10]))
sq_mean.append(np.mean(y_sq_3[:10]))
sq_std.append(np.std(y_sq_3[:10]))
sq_mean.append(np.mean(y_sq_4[:10]))
sq_std.append(np.std(y_sq_4[:10]))
sq_mean.append(np.mean(y_sq_5[:10]))
sq_std.append(np.std(y_sq_5[:10]))
print('Mean -', sq_mean)
print('Std -', sq_std)
# Out:
# Mean - [-16429.1, -15721.9, -15652.4, -15580.2, -15242.3]
# Std - [395.814716755201, 2321.551526458114, 1815.7577041004122, 1586.7331722756667, 1892.4985099069431]
