# %%
import numpy as np
data_pu_1 = np.loadtxt('Trial_2/pushup_1.csv', delimiter=",", usecols=range(3))

# %%
x_pu_1 = np.zeros((data_pu_1.shape[0]//2))
y_pu_1 = np.zeros((data_pu_1.shape[0]//2))
z_pu_1 = np.zeros((data_pu_1.shape[0]//2))
ang_x_pu_1 = np.zeros((data_pu_1.shape[0]//2))
ang_y_pu_1 = np.zeros((data_pu_1.shape[0]//2))
ang_z_pu_1 = np.zeros((data_pu_1.shape[0]//2))
for i in range((data_pu_1.shape[0])//2):
    x_pu_1[i] = data_pu_1[(2*i),0]
    y_pu_1[i] = data_pu_1[(2*i),1]
    z_pu_1[i] = data_pu_1[(2*i),2]
    ang_x_pu_1[i] = data_pu_1[(2*i)+1,0]
    ang_y_pu_1[i] = data_pu_1[(2*i)+1,1]
    ang_z_pu_1[i] = data_pu_1[(2*i)+1,2]

# %%
import matplotlib.pyplot as plt
t_pu_1 = np.arange(start=0, stop=x_pu_1.shape[0], step=1)

# %%
data_pu_2 = np.loadtxt('Trial_2/pushup_2.csv', delimiter=",", usecols=range(3))

# %%
x_pu_2 = np.zeros((data_pu_2.shape[0]//2))
y_pu_2 = np.zeros((data_pu_2.shape[0]//2))
z_pu_2 = np.zeros((data_pu_2.shape[0]//2))
ang_x_pu_2 = np.zeros((data_pu_2.shape[0]//2))
ang_y_pu_2 = np.zeros((data_pu_2.shape[0]//2))
ang_z_pu_2 = np.zeros((data_pu_2.shape[0]//2))
for i in range((data_pu_2.shape[0])//2):
    x_pu_2[i] = data_pu_2[(2*i),0]
    y_pu_2[i] = data_pu_2[(2*i),1]
    z_pu_2[i] = data_pu_2[(2*i),2]
    ang_x_pu_2[i] = data_pu_2[(2*i)+1,0]
    ang_y_pu_2[i] = data_pu_2[(2*i)+1,1]
    ang_z_pu_2[i] = data_pu_2[(2*i)+1,2]

# %%
t_pu_2 = np.arange(start=0, stop=x_pu_2.shape[0], step=1)

# %%
data_pu_3 = np.loadtxt('Trial_2/pushup_3.csv', delimiter=",", usecols=range(3))

# %%
x_pu_3 = np.zeros((data_pu_3.shape[0]//2))
y_pu_3 = np.zeros((data_pu_3.shape[0]//2))
z_pu_3 = np.zeros((data_pu_3.shape[0]//2))
ang_x_pu_3 = np.zeros((data_pu_3.shape[0]//2))
ang_y_pu_3 = np.zeros((data_pu_3.shape[0]//2))
ang_z_pu_3 = np.zeros((data_pu_3.shape[0]//2))
for i in range((data_pu_3.shape[0])//2):
    x_pu_3[i] = data_pu_3[(2*i),0]
    y_pu_3[i] = data_pu_3[(2*i),1]
    z_pu_3[i] = data_pu_3[(2*i),2]
    ang_x_pu_3[i] = data_pu_3[(2*i)+1,0]
    ang_y_pu_3[i] = data_pu_3[(2*i)+1,1]
    ang_z_pu_3[i] = data_pu_3[(2*i)+1,2]

# %%
t_pu_3 = np.arange(start=0, stop=x_pu_3.shape[0], step=1)

# %%
data_pu_4 = np.loadtxt('Trial_2/pushup_4.csv', delimiter=",", usecols=range(3))

# %%
x_pu_4 = np.zeros((data_pu_4.shape[0]//2))
y_pu_4 = np.zeros((data_pu_4.shape[0]//2))
z_pu_4 = np.zeros((data_pu_4.shape[0]//2))
ang_x_pu_4 = np.zeros((data_pu_4.shape[0]//2))
ang_y_pu_4 = np.zeros((data_pu_4.shape[0]//2))
ang_z_pu_4 = np.zeros((data_pu_4.shape[0]//2))
for i in range((data_pu_4.shape[0])//2):
    x_pu_4[i] = data_pu_4[(2*i),0]
    y_pu_4[i] = data_pu_4[(2*i),1]
    z_pu_4[i] = data_pu_4[(2*i),2]
    ang_x_pu_4[i] = data_pu_4[(2*i)+1,0]
    ang_y_pu_4[i] = data_pu_4[(2*i)+1,1]
    ang_z_pu_4[i] = data_pu_4[(2*i)+1,2]

# %%
t_pu_4 = np.arange(start=0, stop=x_pu_4.shape[0], step=1)

# %%
data_pu_5 = np.loadtxt('Trial_2/pushup_5.csv', delimiter=",", usecols=range(3))

# %%
x_pu_5 = np.zeros((data_pu_5.shape[0]//2))
y_pu_5 = np.zeros((data_pu_5.shape[0]//2))
z_pu_5 = np.zeros((data_pu_5.shape[0]//2))
ang_x_pu_5 = np.zeros((data_pu_5.shape[0]//2))
ang_y_pu_5 = np.zeros((data_pu_5.shape[0]//2))
ang_z_pu_5 = np.zeros((data_pu_5.shape[0]//2))
for i in range((data_pu_5.shape[0])//2):
    x_pu_5[i] = data_pu_5[(2*i),0]
    y_pu_5[i] = data_pu_5[(2*i),1]
    z_pu_5[i] = data_pu_5[(2*i),2]
    ang_x_pu_5[i] = data_pu_5[(2*i)+1,0]
    ang_y_pu_5[i] = data_pu_5[(2*i)+1,1]
    ang_z_pu_5[i] = data_pu_5[(2*i)+1,2]

# %%
t_pu_5 = np.arange(start=0, stop=x_pu_5.shape[0], step=1)

# %%
plt.plot(t_pu_1, y_pu_1)
plt.grid(axis = 'both')
plt.title('Pushp up y')
# Out:
# Text(0.5,1,'Pushp up y')

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_pu_2, y_pu_2)
plt.grid(axis = 'both')

plt.subplot(2, 2, 2)
plt.plot(t_pu_3, y_pu_3)
plt.grid(axis = 'both')

plt.subplot(2, 2, 3)
plt.plot(t_pu_4, y_pu_4)
plt.grid(axis = 'both')

plt.subplot(2, 2, 4)
plt.plot(t_pu_5, y_pu_5)
plt.grid(axis = 'both')

plt.title('y acceleration')
plt.show()

# %%
plt.plot(t_pu_1, z_pu_1)
plt.grid(axis = 'both')
plt.title('Pushp up z')
# Out:
# Text(0.5,1,'Pushp up z')

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_pu_2, z_pu_2)
plt.grid(axis = 'both')

plt.subplot(2, 2, 2)
plt.plot(t_pu_3, z_pu_3)
plt.grid(axis = 'both')

plt.subplot(2, 2, 3)
plt.plot(t_pu_4, z_pu_4)
plt.grid(axis = 'both')

plt.subplot(2, 2, 4)
plt.plot(t_pu_5, z_pu_5)
plt.grid(axis = 'both')

plt.title('z acceleration')
plt.show()

# %%
plt.plot(t_pu_1, ang_y_pu_1)
plt.grid(axis = 'both')
plt.title('Pushp up angle y')
# Out:
# Text(0.5,1,'Pushp up angle y')

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_pu_2, ang_y_pu_2)
plt.grid(axis = 'both')

plt.subplot(2, 2, 2)
plt.plot(t_pu_3, ang_y_pu_3)
plt.grid(axis = 'both')

plt.subplot(2, 2, 3)
plt.plot(t_pu_4, ang_y_pu_4)
plt.grid(axis = 'both')

plt.subplot(2, 2, 4)
plt.plot(t_pu_5, ang_y_pu_5)
plt.grid(axis = 'both')

plt.title('angle y')
plt.show()

# %%
plt.plot(t_pu_1, ang_z_pu_1)
plt.grid(axis = 'both')
plt.title('Pushp up angle z')
# Out:
# Text(0.5,1,'Pushp up angle z')

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_pu_2, ang_z_pu_2)
plt.grid(axis = 'both')

plt.subplot(2, 2, 2)
plt.plot(t_pu_3, ang_z_pu_3)
plt.grid(axis = 'both')

plt.subplot(2, 2, 3)
plt.plot(t_pu_4, ang_z_pu_4)
plt.grid(axis = 'both')

plt.subplot(2, 2, 4)
plt.plot(t_pu_5, ang_z_pu_5)
plt.grid(axis = 'both')

plt.title('angle z')
plt.show()

# %%
pu_mean = []
pu_std = []
pu_mean.append(np.mean(y_pu_1[:20]))
pu_std.append(np.std(y_pu_1[:20]))
pu_mean.append(np.mean(y_pu_2[:20]))
pu_std.append(np.std(y_pu_2[:20]))
pu_mean.append(np.mean(y_pu_3[:20]))
pu_std.append(np.std(y_pu_3[:20]))
pu_mean.append(np.mean(y_pu_4[:20]))
pu_std.append(np.std(y_pu_4[:20]))
pu_mean.append(np.mean(y_pu_5[:20]))
pu_std.append(np.std(y_pu_5[:20]))
print('Mean -', pu_mean)
print('Std -', pu_std)
# Out:
# Mean - [2016.5, -889.6, -1828.85, -2619.35, -1902.55]
# Std - [1759.3062126872628, 2844.6064472963567, 4076.0804736290474, 2974.961869923714, 3835.038780442774]

# %%
pu_mean = []
pu_std = []
pu_mean.append(np.mean(z_pu_1[:20]))
pu_std.append(np.std(z_pu_1[:20]))
pu_mean.append(np.mean(z_pu_2[:20]))
pu_std.append(np.std(z_pu_2[:20]))
pu_mean.append(np.mean(z_pu_3[:20]))
pu_std.append(np.std(z_pu_3[:20]))
pu_mean.append(np.mean(z_pu_4[:20]))
pu_std.append(np.std(z_pu_4[:20]))
pu_mean.append(np.mean(z_pu_5[:20]))
pu_std.append(np.std(z_pu_5[:20]))
print('Mean -', pu_mean)
print('Std -', pu_std)
# Out:
# Mean - [-13677.25, -13806.25, -13438.5, -13230.3, -13564.5]
# Std - [1609.7431122697808, 1546.4241292413928, 1895.0099867810725, 2062.034652958092, 1707.0386492402567]
