# %%
import numpy as np
data_su_1 = np.loadtxt('Trial_2/situp_1.csv', delimiter=",", usecols=range(3))

# %%
x_su_1 = np.zeros((data_su_1.shape[0]//2))
y_su_1 = np.zeros((data_su_1.shape[0]//2))
z_su_1 = np.zeros((data_su_1.shape[0]//2))
ang_x_su_1 = np.zeros((data_su_1.shape[0]//2))
ang_y_su_1 = np.zeros((data_su_1.shape[0]//2))
ang_z_su_1 = np.zeros((data_su_1.shape[0]//2))
for i in range((data_su_1.shape[0])//2):
    x_su_1[i] = data_su_1[(2*i),0]
    y_su_1[i] = data_su_1[(2*i),1]
    z_su_1[i] = data_su_1[(2*i),2]
    ang_x_su_1[i] = data_su_1[(2*i)+1,0]
    ang_y_su_1[i] = data_su_1[(2*i)+1,1]
    ang_z_su_1[i] = data_su_1[(2*i)+1,2]

# %%
import matplotlib.pyplot as plt
t_su_1 = np.arange(start=0, stop=x_su_1.shape[0], step=1)

# %%
y_su_1
0.940319
1568.000000
1147.000000
1705.000000
1159.000000
389.000000
1767.000000
1252.000000
1772.000000
3367.000000
-169.000000
1867.000000
-3609.000000
-5586.000000
-7784.000000
-9471.000000
-8196.000000
-11945.000000
-11644.000000
-14761.000000
# Out:
# array([  1412.,   1833.,   1180.,   1098.,   2982.,   2608.,   2593.,
#         -3343., -10087., -13820., -10599., -14880., -14621., -12523.,
#        -11518., -14029., -16111., -14962., -16016., -17053., -16132.,
#        -14937., -12188., -12649.,  -7372.,  -5722.,   4042.,    814.,
#            57.,    253.,    869.,    955.,   1230.,   1227.,   3260.,
#          5574.,  -1469.,  -6343.,  -7130., -11608., -16421., -11866.,
#        -12645., -13073., -13769., -15104., -15600., -16679., -16885.,
#        -17192., -15894., -15946., -16480., -15508., -13594., -12493.,
#        -11918.,  -8639.,  -5164.,  -5199.,   1025.,    725.,   1476.,
#           633.,    674.,   1989.,    807.,   4154.,   -933.,  -2900.,
#         -3767.,  -8975., -10194., -12419., -12365., -13734., -14044.,
#        -14634., -15654., -15632., -15933., -16690., -17037., -17488.,
#        -16748., -15461., -14114., -13033., -11938.,  -9100.,  -6254.,
# ...

# %%
z_su_1
test = np.array([16175.000000,16641.000000,16596.000000,16681.000000,16854.000000,
                 17334.000000,16954.000000,16424.000000,16966.000000,16273.000000,
                 18228.000000,17176.000000,16162.000000,14657.000000,12758.000000,
                 12523.000000,12305.000000,10401.000000,10125.000000,10087.000000])
print(np.mean(test))
# Out:
# 15066.0

# %%
plt.plot(t_su_1, y_su_1)
plt.grid()
plt.title('Sit up y')
# Out:
# Text(0.5,1,'Sit up y')

# %%
plt.plot(t_su_1, z_su_1)
plt.grid()
plt.title('Sit up z')
# Out:
# Text(0.5,1,'Sit up z')

# %%
plt.plot(t_su_1, ang_y_su_1)
plt.grid()
plt.title('Sit up Angle y')
# Out:
# Text(0.5,1,'Sit up Angle y')

# %%
plt.plot(t_su_1, ang_z_su_1)
plt.grid()
plt.title('Sit up Angle z')
# Out:
# Text(0.5,1,'Sit up Angle z')

# %%
data_su_2 = np.loadtxt('Trial_2/situp_2.csv', delimiter=",", usecols=range(3))

# %%
x_su_2 = np.zeros((data_su_2.shape[0]//2))
y_su_2 = np.zeros((data_su_2.shape[0]//2))
z_su_2 = np.zeros((data_su_2.shape[0]//2))
ang_x_su_2 = np.zeros((data_su_2.shape[0]//2))
ang_y_su_2 = np.zeros((data_su_2.shape[0]//2))
ang_z_su_2 = np.zeros((data_su_2.shape[0]//2))
for i in range((data_su_2.shape[0])//2):
    x_su_2[i] = data_su_2[(2*i),0]
    y_su_2[i] = data_su_2[(2*i),1]
    z_su_2[i] = data_su_2[(2*i),2]
    ang_x_su_2[i] = data_su_2[(2*i)+1,0]
    ang_y_su_2[i] = data_su_2[(2*i)+1,1]
    ang_z_su_2[i] = data_su_2[(2*i)+1,2]

# %%
t_su_2 = np.arange(start=0, stop=x_su_2.shape[0], step=1)

# %%
data_su_3 = np.loadtxt('sit_up_3.csv', delimiter=",", usecols=range(3))

# %%
x_su_3 = np.zeros((data_su_3.shape[0]//2))
y_su_3 = np.zeros((data_su_3.shape[0]//2))
z_su_3 = np.zeros((data_su_3.shape[0]//2))
ang_x_su_3 = np.zeros((data_su_3.shape[0]//2))
ang_y_su_3 = np.zeros((data_su_3.shape[0]//2))
ang_z_su_3 = np.zeros((data_su_3.shape[0]//2))
for i in range((data_su_3.shape[0])//2):
    x_su_3[i] = data_su_3[(2*i),0]
    y_su_3[i] = data_su_3[(2*i),1]
    z_su_3[i] = data_su_3[(2*i),2]
    ang_x_su_3[i] = data_su_3[(2*i)+1,0]
    ang_y_su_3[i] = data_su_3[(2*i)+1,1]
    ang_z_su_3[i] = data_su_3[(2*i)+1,2]

# %%
t_su_3 = np.arange(start=0, stop=x_su_3.shape[0], step=1)

# %%
data_su_4 = np.loadtxt('Trial_2/situp_4.csv', delimiter=",", usecols=range(3))

# %% [raw]
# x_su_4 = np.zeros((data_su_4.shape[0]//2))
# y_su_4 = np.zeros((data_su_4.shape[0]//2))
# z_su_4 = np.zeros((data_su_4.shape[0]//2))
# ang_x_su_4 = np.zeros((data_su_4.shape[0]//2))
# ang_y_su_4 = np.zeros((data_su_4.shape[0]//2))
# ang_z_su_4 = np.zeros((data_su_4.shape[0]//2))
# for i in range((data_su_4.shape[0])//2):
#     x_su_4[i] = data_su_4[(2*i),0]
#     y_su_4[i] = data_su_4[(2*i),1]
#     z_su_4[i] = data_su_4[(2*i),2]
#     ang_x_su_4[i] = data_su_4[(2*i)+1,0]
#     ang_y_su_4[i] = data_su_4[(2*i)+1,1]
#     ang_z_su_4[i] = data_su_4[(2*i)+1,2]

# %%
t_su_4 = np.arange(start=0, stop=x_su_4.shape[0], step=1)

# %%
data_su_5 = np.loadtxt('Trial_2/situp_5.csv', delimiter=",", usecols=range(3))

# %%
x_su_5 = np.zeros((data_su_5.shape[0]//2))
y_su_5 = np.zeros((data_su_5.shape[0]//2))
z_su_5 = np.zeros((data_su_5.shape[0]//2))
ang_x_su_5 = np.zeros((data_su_5.shape[0]//2))
ang_y_su_5 = np.zeros((data_su_5.shape[0]//2))
ang_z_su_5 = np.zeros((data_su_5.shape[0]//2))
for i in range((data_su_5.shape[0])//2):
    x_su_5[i] = data_su_5[(2*i),0]
    y_su_5[i] = data_su_5[(2*i),1]
    z_su_5[i] = data_su_5[(2*i),2]
    ang_x_su_5[i] = data_su_5[(2*i)+1,0]
    ang_y_su_5[i] = data_su_5[(2*i)+1,1]
    ang_z_su_5[i] = data_su_5[(2*i)+1,2]

# %%
t_su_5 = np.arange(start=0, stop=x_su_5.shape[0], step=1)

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_su_2, y_su_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_su_3, y_su_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_su_4, y_su_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_su_5, y_su_5)
plt.grid()


plt.title('y acceleration')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_su_2, z_su_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_su_3, z_su_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_su_4, z_su_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_su_5, z_su_5)
plt.grid()


plt.title('z acceleration')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_su_2, ang_y_su_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_su_3, ang_y_su_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_su_4, ang_y_su_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_su_5, ang_y_su_5)
plt.grid()


plt.title('angle y')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))


plt.subplot(2, 2, 1)
plt.plot(t_su_2, ang_z_su_2)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(t_su_3, ang_z_su_3)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t_su_4, ang_z_su_4)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(t_su_5, ang_z_su_5)
plt.grid()


plt.title('angle z')
plt.show()

# %%
su_mean = []
su_std = []
su_mean.append(np.mean(y_su_1[:30]))
su_std.append(np.std(y_su_1[:30]))
su_mean.append(np.mean(y_su_2[:30]))
su_std.append(np.std(y_su_2[:30]))
su_mean.append(np.mean(y_su_3[:30]))
su_std.append(np.std(y_su_3[:30]))
su_mean.append(np.mean(y_su_4[:30]))
su_std.append(np.std(y_su_4[:30]))
su_mean.append(np.mean(y_su_5[:30]))
su_std.append(np.std(y_su_5[:30]))
print('Mean -', su_mean)
print('Std -', su_std)
# Out:
# Mean - [-7323.0, -8844.9, -7256.966666666666, -6807.366666666667, -7422.5]
# Std - [7496.938512930907, 7847.820815784893, 6571.065867286845, 7836.0092797432435, 8094.790488332604]

# %%
su_mean = []
su_std = []
su_mean.append(np.mean(z_su_1[:30]))
su_std.append(np.std(z_su_1[:30]))
su_mean.append(np.mean(z_su_2[:30]))
su_std.append(np.std(z_su_2[:30]))
su_mean.append(np.mean(z_su_3[:30]))
su_std.append(np.std(z_su_3[:30]))
su_mean.append(np.mean(z_su_4[:30]))
su_std.append(np.std(z_su_4[:30]))
su_mean.append(np.mean(z_su_5[:30]))
su_std.append(np.std(z_su_5[:30]))
print('Mean -', su_mean)
print('Std -', su_std)
# Out:
# Mean - [11929.5, 10863.466666666667, 12924.766666666666, 12127.766666666666, 11295.933333333332]
# Std - [4194.075486127227, 5513.504153339226, 4923.755096017222, 4908.193345032591, 5461.028767142282]

# %%
su_mean = []
su_std = []
su_mean.append(np.mean(y_su_1[:20]))
su_std.append(np.std(y_su_1[:20]))
su_mean.append(np.mean(y_su_2[:20]))
su_std.append(np.std(y_su_2[:20]))
su_mean.append(np.mean(y_su_3[:20]))
su_std.append(np.std(y_su_3[:20]))
su_mean.append(np.mean(y_su_4[:20]))
su_std.append(np.std(y_su_4[:20]))
su_mean.append(np.mean(y_su_5[:20]))
su_std.append(np.std(y_su_5[:20]))
print('Mean -', su_mean)
print('Std -', su_std)
# Out:
# Mean - [-7792.8, -9678.6, -5067.95, -4075.5, -8329.4]
# Std - [7695.136844787102, 8014.984936978984, 6013.514483852184, 7628.7101367138075, 7978.965662289818]

# %%
su_mean = []
su_std = []
su_mean.append(np.mean(z_su_1[:20]))
su_std.append(np.std(z_su_1[:20]))
su_mean.append(np.mean(z_su_2[:20]))
su_std.append(np.std(z_su_2[:20]))
su_mean.append(np.mean(z_su_3[:20]))
su_std.append(np.std(z_su_3[:20]))
su_mean.append(np.mean(z_su_4[:20]))
su_std.append(np.std(z_su_4[:20]))
su_mean.append(np.mean(z_su_5[:20]))
su_std.append(np.std(z_su_5[:20]))
print('Mean -', su_mean)
print('Std -', su_std)
# Out:
# Mean - [11692.0, 9983.35, 14389.0, 13417.1, 10607.25]
# Std - [4430.7045827949305, 5873.642960505856, 3825.5056528516593, 4140.992693787324, 5827.868382822317]

# %%
su_mean = []
su_std = []
su_mean.append(np.mean(z_su_1[:10]))
su_std.append(np.std(z_su_1[:10]))
su_mean.append(np.mean(z_su_2[:10]))
su_std.append(np.std(z_su_2[:10]))
su_mean.append(np.mean(z_su_3[:10]))
su_std.append(np.std(z_su_3[:10]))
su_mean.append(np.mean(z_su_4[:10]))
su_std.append(np.std(z_su_4[:10]))
su_mean.append(np.mean(z_su_5[:10]))
su_std.append(np.std(z_su_5[:10]))
print('Mean -', su_mean)
print('Std -', su_std)
# Out:
# Mean - [15253.3, 14845.6, 16450.8, 16327.9, 15797.4]
# Std - [2839.7426661583263, 4038.4821950827018, 591.5934076711809, 294.62126535604995, 2146.617161955061]
